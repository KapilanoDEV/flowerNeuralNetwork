# %%
import numpy

# %%
def NN(m1, m2, w1, w2, b):
    z = m1 * w1 + m2 * w2 + b
    return sigmoid(z)

def sigmoid(x):
    return 1/(1 + numpy.exp(-x))

# %%
w1 = numpy.random.randn()
w2 = numpy.random.randn()
b = numpy.random.randn()

# %%
w1
# Out:
# -2.641891532805129

# %%
w2
# Out:
# 0.14758652170117822

# %%
NN(3, 1.5, w1, w2, b)
# Out:
# np.float64(0.0006695021082617317)

# %%
NN(2, .5, w1, w2, b)
# Out:
# np.float64(0.008049992852919543)
